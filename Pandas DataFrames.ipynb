# %%
# 🔶 1. What is Pandas?
# 🐼 Pandas is a Python library used to store, process, and analyze tabular data (like Excel sheet).

#import pandas as pd

# %%
#  2. What is a DataFrame?
# 📌 DataFrame = Table-like structure (rows + columns), like Excel or CSV.

# %%
#data =  pd.DataFrame(.......)

# %%
#  3. Create DataFrame (Manual)
# ✅ Using dictionary:

# %%
import pandas as pd
data= {

'Name': ['Ramu', 'Seetha', 'balaji'],
    'Age': [25, 23, 26],
    'City': ['Hyderabad', 'Chennai', 'Bangalore']
    
}

# %%
print(data)
# Out:
# {'Name': ['Ramu', 'Seetha', 'balaji'], 'Age': [25, 23, 26], 'City': ['Hyderabad', 'Chennai', 'Bangalore']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age       City
# 0    Ramu   25  Hyderabad
# 1  Seetha   23    Chennai
# 2  balaji   26  Bangalore

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\91944\Desktop\Foundations of Data Science\student-data.csv")
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences passed
# 0       no       no       4         3      4    1    1      3        6     no
# 1      yes       no       5         3      3    1    1      3        4     no
# 2      yes       no       4         3      2    2    3      3       10    yes
# 3      yes      yes       3         2      2    1    1      5        2    yes
# 4       no       no       4         3      2    1    2      5        4    yes
#
# [5 rows x 31 columns]

# %%
df.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences passed
# 0       no       no       4         3      4    1    1      3        6     no
# 1      yes       no       5         3      3    1    1      3        4     no
#
# [2 rows x 31 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 390  ...       no       no       5         5      4    4    5      4       11
# 391  ...      yes       no       2         4      5    3    4      2        3
# 392  ...       no       no       5         5      3    3    3      3        3
# 393  ...      yes       no       4         4      1    3    4      5        0
# 394  ...      yes       no       3         2      3    3    3      5        5
#
#     passed
# 390     no
# 391    yes
# ...

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  ...  \
# 394     MS   M   19       U     LE3       T     1     1  other  at_home  ...
#
#     internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 394      yes       no       3         2      3    3    3      5        5
#
#     passed
# 394     no
#
# [1 rows x 31 columns]

# %%
df.shape
# Out:
# (395, 31)

# %%
df[:]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df[1:10]
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 1  ...      yes       no       5         3      3    1    1      3        4
# ...

# %%
df[::-1]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 390     MS   M   20       U     LE3       A     2     2  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
#
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'passed'],
#       dtype='object')

# %%
df.school #to print any particular column we need to use df.that_col_name
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
#df.freetime or #We can access in anyway
df['freetime']
# Out:
# 0      3
# 1      3
# 2      3
# 3      2
# 4      3
#       ..
# 390    5
# 391    4
# 392    5
# 393    4
# 394    2
# Name: freetime, Length: 395, dtype: int64

# %%
#To get access of two or more cols then u need to use two brackets
df[['freetime','age']]
# Out:
#      freetime  age
# 0           3   18
# 1           3   17
# 2           3   15
# 3           2   15
# 4           3   16
# ..        ...  ...
# 390         5   20
# 391         4   17
# 392         5   21
# 393         4   18
# 394         2   19
#
# [395 rows x 2 columns]

# %%
df[['freetime','age']].head()
# Out:
#    freetime  age
# 0         3   18
# 1         3   17
# 2         3   15
# 3         2   15
# 4         3   16

# %%
df['age'].max()
# Out:
# 22

# %%
df['age'].min()
# Out:
# 15

# %%
df['age'].mean()
# Out:
# 16.696202531645568

# %%
df['age'].mode()
# Out:
# 0    16
# Name: age, dtype: int64

# %%
df['age'].median()
# Out:
# 17.0

# %%
df['age'].describe()
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
df['age'].std()
# Out:
# 1.2760427246056245

# %%
df['age'].count()
# Out:
# 395

# %%
df.shape
# Out:
# (395, 31)

# %%
df[df['age']>20]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
#
#      ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# 247  ...      yes      yes       5         4      5    5    5      1       16
# 392  ...       no       no       5         5      3    3    3      3        3
#
#     passed
# 247     no
# 392     no
#
# [2 rows x 31 columns]

# %%
df[df['freetime']<5]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df[df['absences']>5].head(10)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 18     GP   M   17       U     GT3       T     3     2  services  services
# 25     GP   F   16       U     GT3       T     2     2  services  services
# 29     GP   M   16       U     GT3       T     4     4   teacher   teacher
# 37     GP   M   16       R     GT3       A     4     4     other   teacher
# 39     GP   F   15       R     GT3       T     2     2   at_home     other
#
#     ... internet romantic  famrel  freetime  goout Dalc Walc health absences  \
# ...

# %%
# Position-based indexing (like array)

# %%
df.iloc[0]
# Out:
# school             GP
# sex                 F
# age                18
# address             U
# famsize           GT3
# Pstatus             A
# Medu                4
# Fedu                4
# Mjob          at_home
# Fjob          teacher
# reason         course
# guardian       mother
# traveltime          2
# studytime           2
# failures            0
# schoolsup         yes
# famsup             no
# paid               no
# activities         no
# nursery           yes
# higher            yes
# internet           no
# romantic           no
# famrel              4
# freetime            3
# goout               4
# Dalc                1
# Walc                1
# health              3
# absences            6
# passed             no
# Name: 0, dtype: object

# %%
df.iloc[10]
# Out:
# school                GP
# sex                    F
# age                   15
# address                U
# famsize              GT3
# Pstatus                T
# Medu                   4
# Fedu                   4
# Mjob             teacher
# Fjob              health
# reason        reputation
# guardian          mother
# traveltime             1
# studytime              2
# failures               0
# schoolsup             no
# famsup               yes
# paid                 yes
# activities            no
# nursery              yes
# higher               yes
# internet             yes
# romantic              no
# famrel                 3
# freetime               3
# goout                  3
# Dalc                   1
# Walc                   2
# health                 2
# absences               0
# passed                no
# Name: 10, dtype: object

# %%
df.shape
# Out:
# (395, 31)

# %%
df.iloc[394]
# Out:
# school             MS
# sex                 M
# age                19
# address             U
# famsize           LE3
# Pstatus             T
# Medu                1
# Fedu                1
# Mjob            other
# Fjob          at_home
# reason         course
# guardian       father
# traveltime          1
# studytime           1
# failures            0
# schoolsup          no
# famsup             no
# paid               no
# activities         no
# nursery           yes
# higher            yes
# internet          yes
# romantic           no
# famrel              3
# freetime            2
# goout               3
# Dalc                3
# Walc                3
# health              5
# absences            5
# passed             no
# Name: 394, dtype: object

# %%
#to get to know about any particular row and column

# %%
df.iloc[0,1]  #0th row, 1 st col
# Out:
# 'F'

# %%
df.loc[0]
# Out:
# school             GP
# sex                 F
# age                18
# address             U
# famsize           GT3
# Pstatus             A
# Medu                4
# Fedu                4
# Mjob          at_home
# Fjob          teacher
# reason         course
# guardian       mother
# traveltime          2
# studytime           2
# failures            0
# schoolsup         yes
# famsup             no
# paid               no
# activities         no
# nursery           yes
# higher            yes
# internet           no
# romantic           no
# famrel              4
# freetime            3
# goout               4
# Dalc                1
# Walc                1
# health              3
# absences            6
# passed             no
# Name: 0, dtype: object

# %%
# Feature	 loc	      iloc
# Full Form	label-based location	integer location
# Works with	Row labels / names	Row numbers / positions
# Use case	Use when you know row labels	Use when you know row numbers
# Supports conditions	✅ Yes	❌ No (Only numeric indexing)
# Syntax	df.loc[row_label, column_name]	df.iloc[row_number, column_index]

# %%
import pandas as pd
df2 = pd.DataFrame({
    'name': ['Seetha', 'Balaji', 'lucky'],
    'age': [23, 24, 25]
}, index=[101, 102, 103])

print(df2)
# Out:
#        name  age
# 101  Seetha   23
# 102  Balaji   24
# 103   lucky   25

# %%
df2.iloc[0]
# Out:
# name    Seetha
# age         23
# Name: 101, dtype: object

# %%
df2.loc[101]
# Out:
# name    Seetha
# age         23
# Name: 101, dtype: object
