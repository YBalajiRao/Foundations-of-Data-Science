# %%
#  What is Linear Regression?
# Linear Regression is a method to model the relationship between:

# an input variable (X) 👉 e.g., hours studied

# and an output variable (Y) 👉 e.g., marks obtained

# We try to draw a straight line that best fits the data.

# %%
# 💡 Real-Life Example
# | Hours Studied (X) | Marks Obtained (Y) |
# | ----------------- | ------------------ |
# | 1                 | 10                 |
# | 2                 | 20                 |
# | 3                 | 30                 |
# | 4                 | 40                 |
# | 5                 | 50                 |

# %%
# 🧪 Linear Regression Formula
# Y=mX+c
# Where:

# m = slope (how fast Y changes as X changes)

# c = intercept (value of Y when X = 0)

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Input: Hours studied
X = [[1], [2], [3], [4], [5]]  # 2D list

# Output: Marks obtained
y = [10, 20, 30, 40, 50]

# %%
model=LinearRegression() # here we are created the LR model

# %% [markdown]
# <!-- model.fit(X,Y)       fit the model to the data -->

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
predicted_marks=model.predict([[6]])
print(predicted_marks)
# Out:
# [60.]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\91944\Desktop\Foundations of Data Science\house_sales.csv")
print(data)
# Out:
#                   datesold  postcode   price propertyType  bedrooms
# 0      2007-02-07 00:00:00      2607  525000        house         4
# 1      2007-02-27 00:00:00      2906  290000        house         3
# 2      2007-03-07 00:00:00      2905  328000        house         3
# 3      2007-03-09 00:00:00      2905  380000        house         4
# 4      2007-03-21 00:00:00      2906  310000        house         3
# ...                    ...       ...     ...          ...       ...
# 29575  2019-07-25 00:00:00      2900  500000         unit         3
# 29576  2019-07-25 00:00:00      2612  560000         unit         2
# 29577  2019-07-26 00:00:00      2912  464950         unit         2
# 29578  2019-07-26 00:00:00      2601  589000         unit         2
# 29579  2019-07-26 00:00:00      2612  775000         unit         2
#
# [29580 rows x 5 columns]

# %%
X=data['bedrooms']
Y=data['price']

# %%
print(X)
# Out:
# 0        4
# 1        3
# 2        3
# 3        4
# 4        3
#         ..
# 29575    3
# 29576    2
# 29577    2
# 29578    2
# 29579    2
# Name: bedrooms, Length: 29580, dtype: int64

# %%
print(Y)
# Out:
# 0        525000
# 1        290000
# 2        328000
# 3        380000
# 4        310000
#           ...
# 29575    500000
# 29576    560000
# 29577    464950
# 29578    589000
# 29579    775000
# Name: price, Length: 29580, dtype: int64

# %%
plt.scatter(X,Y,color='blue')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.title('Scatter plot: Bedroom vs price')
plt.grid(True)
plt.show()

# %%
#now lets create a liner regression model
#step1 is to import the LR class
from sklearn.linear_model import LinearRegression
#We want to use the LinearRegression() 
#algorithm from scikit-learn (a machine learning library)

# %%
#now we need to create model object
model=LinearRegression()
#We are creating an empty model, like a student who is ready to learn from the data.

# %%
#step3 is we need to train the model ( fit it to the data)
model.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 #step3 is we need to train the model ( fit it to the data)
# ----> 2 model.fit(X,Y)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
# ...

# %%
X = data[['bedrooms']]
Y = data['price']

print(X.shape)
print(Y.shape)
# Out:
# (29580, 1)
# (29580,)

# %%
# X = input features → must be 2D: shape = (n_samples, n_features)

# Y = target/output → must be 1D: shape = (n_samples,)

# %%
#step3 is we need to train the model ( fit it to the data)
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.predict([[6]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1004043.07403048])

# %%
model.coef_          #slope(m) also called coefficient
# Out:
# array([143393.10909542])

# %%
#intercept(c) - also called as bias
model.intercept_
# Out:
# 143684.41945794568

# %%
bedrooms=6
slope=143393.10909542
intercept=143684.41945794568
predicted_price= slope * bedrooms + intercept
print(predicted_price)
# Out:
# 1004043.0740304657
